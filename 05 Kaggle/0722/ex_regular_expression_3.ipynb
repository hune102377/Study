# %%
# 임의의 위키 페이지에서 모든 링크 목록 가져오기
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
for link in bs.find_all('a'):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #searchInput
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# #cite_note-1
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Wikipedia:Citation_needed
# http://baconbros.com/
# #cite_note-2
# #cite_note-actor-3
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/X-Men:_First_Class
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/Streaming_television
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-6
# /wiki/EE_Limited
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Personal_life
# #Accolades
# #Awards_and_nominations
# #Other_honors
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-3
# #cite_note-actor-3
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_High_School
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-6
# #cite_note-bacon-7
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-7
# #cite_note-16
# #cite_note-17
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-18
# /wiki/Tremors_(1990_film)
# #cite_note-19
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-20
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-21
# /wiki/A_Few_Good_Men_(film)
# #cite_note-22
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-23
# /wiki/Sleepers_(film)
# #cite_note-24
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-25
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-26
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/File:Kevin_Bacon_Cannes_2004.jpg
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-27
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-28
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-29
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# #cite_note-30
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-31
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/File:Black_Mass_PC_04_(21429102646).jpg
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-32
# #cite_note-33
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-34
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-35
# #cite_note-36
# /wiki/The_Following
# #cite_note-37
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-38
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# #cite_note-39
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# #cite_note-40
# #cite_note-41
# #cite_note-42
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# #cite_note-43
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# #cite_note-44
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-45
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# #cite_note-46
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-47
# /wiki/Tracy_Pollan
# #cite_note-48
# /wiki/Separation_of_church_and_state_in_the_United_States
# #cite_note-49
# #cite_note-50
# /wiki/The_Times
# /wiki/God
# #cite_note-51
# /wiki/Antireligion
# #cite_note-52
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-53
# #cite_note-54
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-55
# #cite_note-56
# #cite_note-57
# #cite_note-58
# /wiki/Apollo_13_(film)
# #cite_note-59
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-60
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-61
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-62
# /wiki/Denver_Film_Festival
# #cite_note-63
# /wiki/Phoenix_Film_Festival
# #cite_note-64
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-65
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-66
# /wiki/Seattle_International_Film_Festival
# #cite_note-67
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# http://www.geneall.net/U/per_page.php?id=1014399
# #cite_ref-2
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_3-0
# #cite_ref-actor_3-1
# #cite_ref-actor_3-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_6-0
# #cite_ref-walk_6-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# https://web.archive.org/web/20190403203113/https://www.biography.com/news/kevin-bacon-biography-facts
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# https://web.archive.org/web/20080830035710/http://www.time.com/time/magazine/article/0,9171,950019,00.html
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-19
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_20-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-21
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-22
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-23
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-24
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_25-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-26
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-27
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-28
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-29
# https://archive.today/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-30
# https://web.archive.org/web/20140802203026/http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-31
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-32
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-33
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_34-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_35-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# https://ghostarchive.org/varchive/youtube/20211211/qlUG8F9uVgM
# #cite_ref-36
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-37
# http://www.fox.com/the-following/
# #cite_ref-38
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-39
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-40
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-41
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-42
# https://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-43
# http://www.sixdegrees.org/
# #cite_ref-44
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-45
# https://web.archive.org/web/20121112081753/http://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-46
# http://baconbros.com/
# #cite_ref-47
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-48
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-49
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-50
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-51
# #cite_ref-52
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_53-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-54
# #cite_ref-55
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-56
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-57
# http://www.drawtheline.org/sign-now/
# #cite_ref-58
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-59
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-60
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-61
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# #cite_ref-62
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-63
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-64
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-65
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-66
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-67
# https://www.imdb.com/event/ev0000600/2015/1/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.iobdb.com/CreditableEntity/5597
# /wiki/Internet_Off-Broadway_Database
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# https://en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# https://en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Template:Golden_Globe_Best_Actor_TV_Miniseries_Film
# /wiki/Template_talk:Golden_Globe_Best_Actor_TV_Miniseries_Film
# https://en.wikipedia.org/w/index.php?title=Template:Golden_Globe_Best_Actor_TV_Miniseries_Film&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# https://en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Patrick_Stewart
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165#identifiers
# /wiki/ISNI_(identifier)
# https://isni.org/isni/0000000121291300
# /wiki/VIAF_(identifier)
# https://viaf.org/viaf/39570812
# https://www.worldcat.org/identities/lccn-n88034930/
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# https://d-nb.info/gnd/124109659
# http://uli.nli.org.il/F/?func=find-b&local_base=NLX10&find_code=UID&request=987007454685905171
# https://id.loc.gov/authorities/names/n88034930
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# https://nla.gov.au/anbd.aut-an36021861
# https://librarian.nl.go.kr/LI/contents/L20101000000.do?id=KAC2020K8226
# http://data.bibliotheken.nl/id/thes/p147880998
# http://mak.bn.org.pl/cgi-bin/KHW/makwww.exe?BM=1&NU=1&IM=4&WI=9810630778405606
# http://id.worldcat.org/fast/242183/
# /wiki/MBA_(identifier)
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/RERO_(identifier)
# http://data.rero.ch/02-A016294166
# https://snaccooperative.org/ark:/99166/w6w67gw2
# /wiki/SUDOC_(identifier)
# https://www.idref.fr/084292652
# https://www.idref.fr/067287832
# /wiki/Trove_(identifier)
# https://trove.nla.gov.au/people/1189569
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=1098757395
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Short_description_is_different_from_Wikidata
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_October_2021
# /wiki/Category:Articles_with_hCards
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:IBDB_name_template_using_Wikidata
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Articles_with_ISNI_identifiers
# /wiki/Category:Articles_with_VIAF_identifiers
# /wiki/Category:Articles_with_WORLDCATID_identifiers
# /wiki/Category:Articles_with_BIBSYS_identifiers
# /wiki/Category:Articles_with_BNE_identifiers
# /wiki/Category:Articles_with_BNF_identifiers
# /wiki/Category:Articles_with_GND_identifiers
# /wiki/Category:Articles_with_J9U_identifiers
# /wiki/Category:Articles_with_LCCN_identifiers
# /wiki/Category:Articles_with_LNB_identifiers
# /wiki/Category:Articles_with_NKC_identifiers
# /wiki/Category:Articles_with_NLA_identifiers
# /wiki/Category:Articles_with_NLK_identifiers
# /wiki/Category:Articles_with_NTA_identifiers
# /wiki/Category:Articles_with_PLWABN_identifiers
# /wiki/Category:Articles_with_FAST_identifiers
# /wiki/Category:Articles_with_MusicBrainz_identifiers
# /wiki/Category:Articles_with_RERO_identifiers
# /wiki/Category:Articles_with_SNAC-ID_identifiers
# /wiki/Category:Articles_with_SUDOC_identifiers
# /wiki/Category:Articles_with_Trove_identifiers
# /wiki/Category:Articles_with_multiple_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=1098757395
# /w/index.php?title=Kevin_Bacon&action=info
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=1098757395&wpFormIdentifier=titleform
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:DownloadAsPdf&page=Kevin_Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://commons.wikimedia.org/wiki/Kevin_Bacon
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eo.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_Beikons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://arz.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://ms.wikipedia.org/wiki/Kevin_Bacon
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://wuu.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://zh-yue.wikipedia.org/wiki/%E5%A5%87%E9%9B%B2%E8%B2%9D%E6%A0%B9
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://developer.wikimedia.org
# https://stats.wikimedia.org/#/en.wikipedia.org
# https://foundation.wikimedia.org/wiki/Cookie_statement
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# ###### 불필요한 정보를 걸러내기 위해 위키백과 페이지를 분석할 필요

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

html = urlopen('https://en.wikipedia.org/wiki/Kevin_Bacon')
bs = BeautifulSoup(html, 'html.parser')
body_content = bs.find('div', {'id' : 'bodyContent'})

# 정규식 시작... 정규식 끝
# (/wiki/): '/wiki/'를 포함
# ((?1:).)*: ':' 콜론이 없는 문자열 및 임의의 문자가 0회 이상 반복되는 문자열 검색

pattern = '^(/wiki/)((?!:).)*$'
for link in body_content.find_all('a', href=re.compile(pattern)):
    if 'href' in link.attrs:
        print(link.attrs['href'])
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia,_Pennsylvania
# /wiki/Kevin_Bacon_filmography
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Balto_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Animal_House
# /wiki/Diner_(1982_film)
# /wiki/Tremors_(1990_film)
# /wiki/Crazy,_Stupid,_Love
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Flatliners
# /wiki/The_River_Wild
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/Hollow_Man
# /wiki/Frost/Nixon_(film)
# /wiki/Black_Mass_(film)
# /wiki/Patriots_Day_(film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/Streaming_television
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/EE_Limited
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Julia_R._Masterman_High_School
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Kevin_Bacon_filmography
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Getting_Out
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(1982_film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(1990_film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Cannes_Film_Festival
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Toronto_Film_Festival
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(1990_film)
# /wiki/EE_(telecommunications_company)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Social_networking_service
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/IMDb
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/Separation_of_church_and_state_in_the_United_States
# /wiki/The_Times
# /wiki/God
# /wiki/Antireligion
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/Chlotrudis_Awards
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Internet_Off-Broadway_Database
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/The_Bacon_Brothers
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Joaquin_Phoenix
# /wiki/Chadwick_Boseman
# /wiki/Will_Smith
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Russell_Crowe
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Patrick_Stewart
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Sam_Rockwell
# /wiki/Mark_Ruffalo
# /wiki/Michael_Keaton
# /wiki/ISNI_(identifier)
# /wiki/VIAF_(identifier)
# /wiki/MBA_(identifier)
# /wiki/RERO_(identifier)
# /wiki/SUDOC_(identifier)
# /wiki/Trove_(identifier)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
i = 1
def getLinks(pageUrl):
    global i
    i += 1
    if i <= 3:
        global pages
        html = urlopen('https://en.wikipedia.org{}'.format(pageUrl))
        bs = BeautifulSoup(html, 'html.parser')
        try :
            print(bs.h1.get_text())
            print(bs.find(id='mw-content-text').find_all('p')[0])
            print(bs.find(id='ca-edit').find('span').find('a').attrs['href'])
        except AttributeError:
            print('this page is missing something! Continuing')
        
        for link in bs.find_all('a', href=re.compile('^(/wiki/)')):
            if 'href' in link.attrs:
                if link.attrs['href'] not in pages:
                    newPage = link.attrs['href']
                    print('-'*20)
                    print(newPage)
                    pages.add(newPage)
                    getLinks(newPage)
                    
getLinks('')
# Out:
# Main Page
# <p>The <b><a href="/wiki/Anglo-Scottish_war_(1650%E2%80%931652)" title="Anglo-Scottish war (1650–1652)">Anglo-Scottish War</a></b> was the final conflict in the British <a href="/wiki/Wars_of_the_Three_Kingdoms" title="Wars of the Three Kingdoms">Wars of the Three Kingdoms</a>. When the Royalists were defeated in 1648, after the <a href="/wiki/First_English_Civil_War" title="First English Civil War">First</a> and <a href="/wiki/Second_English_Civil_War" title="Second English Civil War">Second English Civil Wars</a>, the <a href="/wiki/Rump_Parliament" title="Rump Parliament">English government</a> ordered the <a href="/wiki/Execution_of_Charles_I" title="Execution of Charles I">execution of their king</a>, <a href="/wiki/Charles_I_of_England" title="Charles I of England">Charles I</a>, who was also, separately, the <a href="/wiki/Monarchy_of_the_United_Kingdom#Scottish_monarchy" title="Monarchy of the United Kingdom">king of Scotland</a>, then an independent nation. The <a href="/wiki/Parliament_of_Scotland" title="Parliament of Scotland">Parliament of Scotland</a> declared his son, <a href="/wiki/Charles_II_of_England" title="Charles II of England">Charles II</a> <i>(depicted)</i>, to be <a href="/wiki/Monarchy_of_the_United_Kingdom#Personal_union_and_republican_phase" title="Monarchy of the United Kingdom">King of Britain</a>. Seeing this as a threat, an English army under <a href="/wiki/Oliver_Cromwell" title="Oliver Cromwell">Oliver Cromwell</a> invaded Scotland on 22 July 1650. After a month of manoeuvring Cromwell <a href="/wiki/Battle_of_Dunbar_(1650)" title="Battle of Dunbar (1650)">heavily defeated the Scots at Dunbar</a>. In July 1651 the English crossed the <a href="/wiki/Firth_of_Forth" title="Firth of Forth">Firth of Forth</a> and <a href="/wiki/Battle_of_Inverkeithing" title="Battle of Inverkeithing">defeated the Scots  at Inverkeithing</a>, cutting their army off from supply and reinforcements. In desperation Charles II invaded England in August. Cromwell pursued, brought the badly outnumbered Scots to battle on 3 September 1651 and <a href="/wiki/Battle_of_Worcester" title="Battle of Worcester">completely defeated them</a>, ending the Wars of the Three Kingdoms and resulting in Scotland's absorption into the <a href="/wiki/Commonwealth_of_England" title="Commonwealth of England">English Commonwealth</a>. (<b><a href="/wiki/Anglo-Scottish_war_(1650%E2%80%931652)" title="Anglo-Scottish war (1650–1652)">Full article...</a></b>)
# </p>
# this page is missing something! Continuing
# --------------------
# /wiki/Wikipedia
# Wikipedia
# <p class="mw-empty-elt">
# </p>
# this page is missing something! Continuing
# --------------------
# /wiki/Wikipedia:Protection_policy#semi
# --------------------
# /wiki/Main_Page
# --------------------
# /wiki/English_Wikipedia
# --------------------
# /wiki/List_of_Wikipedias
# --------------------
# /wiki/Wikipedia_(disambiguation)
# --------------------
# /wiki/File:Wikipedia-logo-v2.svg
# --------------------
# /wiki/File:Wikipedia-logo-textonly.svg
# --------------------
# /wiki/Wikipedia_logo
# --------------------
# /wiki/Glyph
# --------------------
# /wiki/Writing_system
# --------------------
# /wiki/File:Wikipedia_Portal_Screenshot_(2022).svg
# --------------------
# /wiki/Online_encyclopedia
# --------------------
# /wiki/Wikimedia_Foundation
# --------------------
# /wiki/Jimmy_Wales
# --------------------
# /wiki/Larry_Sanger
# --------------------
# /wiki/Registered_user
# --------------------
# /wiki/List_of_Wikipedias#Statistics_totals
# --------------------
# /wiki/Creative_Commons_license
# --------------------
# /wiki/GNU_Free_Documentation_License
# --------------------
# /wiki/LAMP_(software_bundle)
# --------------------
# /wiki/OCLC_(identifier)
# --------------------
# /wiki/Help:IPA/English
# --------------------
# /wiki/File:En-uk-Wikipedia.ogg
# --------------------
# /wiki/Help:Pronunciation_respelling_key
# --------------------
# /wiki/File:En-us-Wikipedia.ogg
# --------------------
# /wiki/Multilingualism
# --------------------
# /wiki/Online_volunteering
# --------------------
# /wiki/Open_collaboration
# --------------------
# /wiki/Wiki
# --------------------
# /wiki/Wikipedians
# --------------------
# /wiki/Reference_work
# --------------------
# /wiki/List_of_most_visited_websites
# --------------------
# /wiki/Similarweb
# --------------------
# /wiki/Alexa_Internet
# --------------------
# /wiki/501(c)(3)_organization
# --------------------
# /wiki/Blend_word
# --------------------
# /wiki/Spontaneous_order
# --------------------
# /wiki/Friedrich_Hayek
# --------------------
# /wiki/Austrian_School
# --------------------
# /wiki/Mises_Institute
# --------------------
# /wiki/Mark_Thornton
# --------------------
# /wiki/Time_(magazine)
# --------------------
# /wiki/Democratization_of_knowledge
# --------------------
# /wiki/Criticism_of_Wikipedia
# --------------------
# /wiki/Criticism_of_Wikipedia#Systemic_bias_in_coverage
# --------------------
# /wiki/Gender_bias_on_Wikipedia
# --------------------
# /wiki/Ideological_bias_on_Wikipedia
# --------------------
# /wiki/Reliability_of_Wikipedia
# --------------------
# /wiki/Wikipedia_coverage_of_American_politics
# --------------------
# /wiki/Wikipedia_coverage_of_the_COVID-19_pandemic
# --------------------
# /wiki/Censorship_of_Wikipedia
# --------------------
# /wiki/Wikipedia_in_culture
# --------------------
# /wiki/Bibliography_of_Wikipedia
# --------------------
# /wiki/List_of_films_about_Wikipedia
# --------------------
# /wiki/Academic_studies_about_Wikipedia
# --------------------
# /wiki/Facebook
# --------------------
# /wiki/YouTube
# --------------------
# /wiki/Fake_news
# --------------------
# /wiki/Wikipedia_and_fact-checking
# --------------------
# /wiki/Breaking_news
# --------------------
# /wiki/History_of_Wikipedia
# --------------------
# /wiki/File:Jimmy_Wales_September_2015.jpg
# --------------------
# /wiki/File:L_Sanger.jpg
# --------------------
# /wiki/Nupedia
# --------------------
# /wiki/File:Nupedia.svg
# --------------------
# /wiki/Bomis
# --------------------
# /wiki/Web_portal
# --------------------
# /wiki/Editor-in-chief
# --------------------
# /wiki/Free_content
# --------------------
# /wiki/Richard_Stallman
# --------------------
# /wiki/Domain_name
# --------------------
# /wiki/File:English_Wikipedia_HomePage_2001-12-20.png
# --------------------
# /wiki/Slashdot
# --------------------
# /wiki/Search_engine
# --------------------
# /wiki/Yongle_Encyclopedia
# --------------------
# /wiki/Ming_Dynasty
# --------------------
# /wiki/Advertising
# --------------------
# /wiki/Spanish_Wikipedia
# --------------------
# /wiki/Fork_(software_development)
# --------------------
# /wiki/Enciclopedia_Libre_Universal_en_Espa%C3%B1ol
# --------------------
# /wiki/Palo_Alto_Research_Center
# --------------------
# /wiki/Rey_Juan_Carlos_University
# --------------------
# /wiki/Madrid
# --------------------
# /wiki/MIT_Technology_Review
# --------------------
# /wiki/The_Atlantic
# --------------------
# /wiki/New_York_(magazine)
# --------------------
# /wiki/File:European_Wikipedias_article_count_2019_map.svg
# --------------------
# /wiki/Cartogram
# --------------------
# /wiki/List_of_most_popular_websites
# --------------------
# /wiki/Comscore
# --------------------
# /wiki/The_New_York_Times
# --------------------
# /wiki/Apple_Inc.
# --------------------
# /wiki/Pageview
# --------------------
# /wiki/Unique_user#Unique_visitor
# --------------------
# /wiki/Stigmergy
# --------------------
# /wiki/United_States_Congress
# --------------------
# /wiki/Stop_Online_Piracy_Act
# --------------------
# /wiki/PROTECT_IP_Act
# --------------------
# /wiki/Protest_against_SOPA_and_PIPA
# --------------------
# /wiki/The_Economic_Times
# --------------------
# /wiki/Knowledge_Graph
# --------------------
# /wiki/Clay_Shirky
# --------------------
# /wiki/Berkman_Klein_Center_for_Internet_%26_Society
# --------------------
# /wiki/274301_Wikipedia
# --------------------
# /wiki/Asteroid
# --------------------
# /wiki/Wikipedia_Monument
# --------------------
# /wiki/Print_Wikipedia
# --------------------
# /wiki/Lunar_lander
# --------------------
# /wiki/Beresheet
# --------------------
# /wiki/Moon
# --------------------
# /wiki/Synthetic_genomics
# --------------------
# /wiki/File:Screenshot_of_English_Wikipedia_article_on_Earth_on_30_March_2021_(cropped).png
# --------------------
# /wiki/Earth
# --------------------
# /wiki/History_of_Wikipedia#Third_decade:_2020–present
# --------------------
# /wiki/Basic_Attention_Token
# --------------------
# /wiki/File:History_Comparison_Example_(Vector).png
# --------------------
# /wiki/Procrastination
# --------------------
# /wiki/Wikipedia_administrators
# --------------------
# /wiki/Columbia_Journalism_Review
# --------------------
# /wiki/German_Wikipedia
# --------------------
# /wiki/File:Wikipedia_editing_interface.png
# --------------------
# /wiki/Help:Recent_changes
# --------------------
# /wiki/Wiki#Controlling_changes
# --------------------
# /wiki/Transaction_cost
# --------------------
# /wiki/Vandalism_on_Wikipedia
# --------------------
# /wiki/File:John_Seigenthaler_Sr._speaking.jpg
# --------------------
# /wiki/John_Seigenthaler
# --------------------
# /wiki/Seigenthaler_incident
# --------------------
# /wiki/Seigenthaler_biography_incident
# --------------------
# /wiki/Assassination_of_John_F._Kennedy
# --------------------
# /wiki/USA_Today
# --------------------
# /wiki/Freedom_Forum
# --------------------
# /wiki/First_Amendment_Center
# --------------------
# /wiki/Vanderbilt_University
# --------------------
# /wiki/Tosh.0
# --------------------
# /wiki/Gender_role
# --------------------
# /wiki/File:Jimbo_at_Fosdem_cropped.jpg
# --------------------
# /wiki/60_Minutes
# --------------------
# /wiki/CBS
# --------------------
# /wiki/Fosdem
# --------------------
# /wiki/Copyright
# --------------------
# /wiki/Virginia
# --------------------
# /wiki/Wikipedia:Enforcement
# --------------------
# /wiki/Deletion_of_articles_on_Wikipedia
# --------------------
# /wiki/Notability_in_the_English_Wikipedia
# --------------------
# /wiki/Wikipedia:Administration
# --------------------
# /wiki/Anarchy
# --------------------
# /wiki/Democracy
# --------------------
# /wiki/Wikipedia:User_access_levels
# --------------------
# /wiki/Administrators_(Wikipedia)
# --------------------
# /wiki/Consensus_decision-making
# --------------------
# /wiki/Joseph_M._Reagle_Jr.
# --------------------
# /wiki/Sue_Gardner
# --------------------
# /wiki/Quakers
# --------------------
# /wiki/Facilitator
# --------------------
# /wiki/Arbitration_Committee
# --------------------
# /wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items
# --------------------
# /wiki/Anti-social_behavior
# --------------------
# /wiki/Wikipedia_community
# --------------------
# /wiki/File:Wikimania_-_the_Wikimentary.webm
# --------------------
# /wiki/Wikimania#2005
# --------------------
# /wiki/Frankfurt_am_Main
# --------------------
# /wiki/File:Editing_Hoxne_Hoard_at_the_British_Museum.ogv
# --------------------
# /wiki/British_Museum
# --------------------
# /wiki/Hoxne_Hoard
# --------------------
# /wiki/Cult
# --------------------
# /wiki/Credential
# --------------------
# /wiki/Anti-elitism
# --------------------
# /wiki/Aaron_Swartz
# --------------------
# /wiki/Special:Statistics
# --------------------
# /wiki/Special:ListUsers
# --------------------
# /wiki/Special:ActiveUsers
# --------------------
# /wiki/IP_address
# --------------------
# /wiki/Dartmouth_College
# --------------------
# /wiki/Business_Insider
# --------------------
# /wiki/Henry_Blodget
# --------------------
# /wiki/Yale_University
# --------------------
# /wiki/Brown_University
# --------------------
# /wiki/Andrew_Lih
# --------------------
# /wiki/Cebuano_Wikipedia
# --------------------
# /wiki/Swedish_Wikipedia
# --------------------
# /wiki/French_Wikipedia
# --------------------
# /wiki/Dutch_Wikipedia
# --------------------
# /wiki/Russian_Wikipedia
# --------------------
# /wiki/Italian_Wikipedia
# --------------------
# /wiki/Egyptian_Arabic_Wikipedia
# --------------------
# /wiki/Polish_Wikipedia
# --------------------
# /wiki/Japanese_Wikipedia
# --------------------
# /wiki/Chinese_Wikipedia
# --------------------
# /wiki/Vietnamese_Wikipedia
# --------------------
# /wiki/Waray_Wikipedia
# --------------------
# /wiki/Ukrainian_Wikipedia
# --------------------
# /wiki/Arabic_Wikipedia
# --------------------
# /wiki/File:Most_popular_edition_of_Wikipedia_by_country.svg
# --------------------
# /wiki/File:Wikipedia_page_views_by_language_over_time.png
# --------------------
# /wiki/File:Wikipedia_editors_by_language_over_time.png
# --------------------
# /wiki/Internet_bot
# --------------------
# /wiki/Lsjbot
# --------------------
# /wiki/Portuguese_Wikipedia
# --------------------
# /wiki/Persian_Wikipedia
# --------------------
# /wiki/Catalan_Wikipedia
# --------------------
# /wiki/Serbian_Wikipedia
# --------------------
# /wiki/Indonesian_Wikipedia
# --------------------
# /wiki/Korean_Wikipedia
# --------------------
# /wiki/Norwegian_Wikipedia
# --------------------
# /wiki/Finnish_Wikipedia
# --------------------
# /wiki/File:TurkishWikipedia_block_pageviews_february-may2017.png
# --------------------
# /wiki/Turkish_Wikipedia
# --------------------
# /wiki/Block_of_Wikipedia_in_Turkey
# --------------------
# /wiki/World_Wide_Web
# --------------------
# /wiki/American_and_British_English_spelling_differences
# --------------------
# /wiki/Color
# --------------------
# /wiki/Fair_use
# --------------------
# /wiki/File:User_-_demography.svg
# --------------------
# /wiki/PLOS_One
# --------------------
# /wiki/Simple_English_Wikipedia
# --------------------
# /wiki/File:Editors_English_Wikipedia_History.png
# --------------------
# /wiki/The_Economist
# --------------------
# /wiki/Criticism_of_Wikipedia#Excessive_regulation
# --------------------
# /wiki/Systemic_bias
# --------------------
# /wiki/Edwin_Black
# --------------------
# /wiki/The_Chronicle_of_Higher_Education
# --------------------
# /wiki/The_Journal_of_Academic_Librarianship
# --------------------
# /wiki/Oliver_Kamm
# --------------------
# /wiki/Education_Next
# --------------------
# /wiki/Spin_(propaganda)
# --------------------
# /wiki/Libertarianism
# --------------------
# /wiki/John_Stossel
# --------------------
# /wiki/Plagiarism
# --------------------
# /wiki/Paul_Kennedy_(host)
# --------------------
# /wiki/Canadian_Broadcasting_Corporation
# --------------------
# /wiki/Encyclop%C3%A6dia_Britannica
# --------------------
# /wiki/Confidence_interval
# --------------------
# /wiki/Sample_size_determination
# --------------------
# /wiki/Accountability
# --------------------
# /wiki/Tyler_Cowen
# --------------------
# /wiki/Amy_Bruckman
# --------------------
# /wiki/Utility
# --------------------
# /wiki/Deutsche_Welle
# --------------------
# /wiki/Internet_troll
# --------------------
# /wiki/Spamming
# --------------------
# /wiki/Conflict-of-interest_editing_on_Wikipedia
# --------------------
# /wiki/Katherine_Maher
# --------------------
# /wiki/Stephen_Colbert
# --------------------
# /wiki/The_Colbert_Report
# --------------------
# /wiki/Lecturer
# --------------------
# /wiki/Academia
# --------------------
# /wiki/Primary_source
# --------------------
# /wiki/Email
# --------------------
# /wiki/The_Harvard_Crimson
# --------------------
# /wiki/Harvard_University
# --------------------
# /wiki/Syllabus
# --------------------
# /wiki/American_Library_Association
# --------------------
# /wiki/Michael_Gorman_(librarian)
# --------------------
# /wiki/Google
# --------------------
# /wiki/Wikipedia:Please_clarify
# --------------------
# /wiki/Health_information_on_Wikipedia
# --------------------
# /wiki/Amin_Azzam
# --------------------
# /wiki/University_of_San_Francisco
# --------------------
# /wiki/James_Heilman
# --------------------
# /wiki/Byte#Multiple-byte_units
# --------------------
# /wiki/Deletionism_and_inclusionism_in_Wikipedia
# --------------------
# /wiki/Online_petition_on_Wikipedia_Muhammad_article
# --------------------
# /wiki/Muhammad
# --------------------
# /wiki/File:Wikipedia_content_by_subject.png
# --------------------
# /wiki/New_York_Public_Library_for_the_Performing_Arts
# --------------------
# /wiki/University_of_Minnesota
# --------------------
# /wiki/Oxford_Internet_Institute
# --------------------
# /wiki/The_Guardian
# --------------------
# /wiki/List_of_pornographic_performers_by_decade
# --------------------
# /wiki/List_of_women_writers
# --------------------
# /wiki/Cape_Town
# --------------------
# /wiki/Wikipedia:Vagueness
# --------------------
# /wiki/Internet_culture
# --------------------
# /wiki/Wikipedia:NOTRS
# --------------------
# /wiki/Taha_Yasseri
# --------------------
# /wiki/University_of_Oxford
# --------------------
# /wiki/Counterproductive_work_behavior
# --------------------
# /wiki/George_W._Bush
# --------------------
# /wiki/Anarchism
# --------------------
# /wiki/Oxford
# --------------------
# /wiki/Croatia
# --------------------
# /wiki/Scientology
# --------------------
# /wiki/9/11_conspiracy_theories
# --------------------
# /wiki/Washington_University
# --------------------
# /wiki/Internet_Watch_Foundation_and_Wikipedia
# --------------------
# /wiki/Reporting_of_child_pornography_images_on_Wikimedia_Commons
# --------------------
# /wiki/Wikipedia:Wikipedia_is_not_censored
# --------------------
# /wiki/Feces
# --------------------
# /wiki/Cadaver
# --------------------
# /wiki/Human_penis
# --------------------
# /wiki/Vulva
# --------------------
# /wiki/Nudity
# --------------------
# /wiki/Sexual_content
# --------------------
# /wiki/Masturbation
# --------------------
# /wiki/Ejaculation
# --------------------
# /wiki/Zoophilia
# --------------------
# /wiki/Hardcore_pornography
# --------------------
# /wiki/Child_nudity
# --------------------
# /wiki/Virgin_Killer
# --------------------
# /wiki/Music_of_Germany
# --------------------
# /wiki/Rock_music
# --------------------
# /wiki/Rock_band
# --------------------
# /wiki/Scorpions_(band)
# --------------------
# /wiki/Preadolescence#Prepubescence,_puberty,_and_age_range
# --------------------
# /wiki/Internet_service_provider
# --------------------
# /wiki/Internet_Watch_Foundation
# --------------------
# /wiki/Wikimedia_Commons
# --------------------
# /wiki/United_States_obscenity_law
# --------------------
# /wiki/Pedophilia
# --------------------
# /wiki/Lolicon
# --------------------
# /wiki/Child_pornography_laws_in_the_United_States#Section_1466A
# --------------------
# /wiki/Obscenity#United_States_obscenity_law
# --------------------
# /wiki/Wikipediocracy
# --------------------
# /wiki/Privacy
# --------------------
# /wiki/Public_figure
# --------------------
# /wiki/Cyberspace
# --------------------
# /wiki/Real_life
# --------------------
# /wiki/Meatspace
# --------------------
# /wiki/Tron_(hacker)
# --------------------
# /wiki/Right_to_privacy
# --------------------
# /wiki/Free_and_open-source_software
# --------------------
# /wiki/OTRS
# --------------------
# /wiki/Sexism
# --------------------
# /wiki/Harassment
# --------------------
# /wiki/Edit-a-thon
# --------------------
# /wiki/File:Katherine_Maher.jpg
# --------------------
# /wiki/Lila_Tretikov
# --------------------
# /wiki/Wiktionary
# --------------------
# /wiki/Wikibooks
# --------------------
# /wiki/Wikimedia_movement_affiliates
# --------------------
# /wiki/List_of_Wikimedia_chapters
# --------------------
# /wiki/Catalan_language
# --------------------
# /wiki/MediaWiki
# --------------------
# /wiki/Free_software
# --------------------
# /wiki/Open-source_software
# --------------------
# /wiki/Wiki_software
# --------------------
# /wiki/PHP
# --------------------
# /wiki/MySQL
# --------------------
# /wiki/Macro_(computer_science)
# --------------------
# /wiki/Variable_(programming)
# --------------------
# /wiki/Transclusion
# --------------------
# /wiki/Web_template_system
# --------------------
# /wiki/URL_redirection
# --------------------
# /wiki/GNU_General_Public_License
# --------------------
# /wiki/UseModWiki
# --------------------
# /wiki/Perl
# --------------------
# /wiki/CamelCase
# --------------------
# /wiki/PhpWiki
# --------------------
# /wiki/Magnus_Manske
# --------------------
# /wiki/Exponential_growth
# --------------------
# /wiki/Lee_Daniel_Crocker
# --------------------
# /wiki/Lucene
# --------------------
# /wiki/Elasticsearch
# --------------------
# /wiki/VisualEditor
# --------------------
# /wiki/Wikipedia_bots
# --------------------
# /wiki/Sverker_Johansson
# --------------------
# /wiki/Malaysia_Airlines_Flight_17
# --------------------
# /wiki/Wikimedia_Foundation#Hardware
# --------------------
# /wiki/Varnish_(software)
# --------------------
# /wiki/Apache_Traffic_Server
# --------------------
# /wiki/Linux_Virtual_Server
# --------------------
# /wiki/File:Wikipedia_webrequest_flow_2020.png
# --------------------
# /wiki/Computer_cluster
# --------------------
# /wiki/Linux
# --------------------
# /wiki/Debian
# --------------------
# /wiki/Amsterdam
# --------------------
# /wiki/Equinix
# --------------------
# /wiki/Ashburn,_Virginia
# --------------------
# /wiki/Singapore
# --------------------
# /wiki/Industrial_organization
# --------------------
# /wiki/Wikimedia_project
# --------------------
# /wiki/Wikipedia:The_Wikipedia_Library
# --------------------
# /wiki/Electronic_publishing
# --------------------
# /wiki/ICE_Publishing
# --------------------
# /wiki/Copyleft
# --------------------
# /wiki/Free_Software_Foundation
# --------------------
# /wiki/Wikipedia:Licensing_update
# --------------------
# /wiki/Copyright_law_of_Japan
# --------------------
# /wiki/Creative_Commons
# --------------------
# /wiki/Mirror_site
# --------------------
# /wiki/Reference.com
# --------------------
# /wiki/Answers.com
# --------------------
# /wiki/Wapedia
# --------------------
# /wiki/Mobile_device
# --------------------
# /wiki/Android_(operating_system)
# --------------------
# /wiki/IOS
# --------------------
# /wiki/Wikipedia_App
# --------------------
# /wiki/Microsoft_Bing
# --------------------
# /wiki/Powerset_(company)
# --------------------
# /wiki/DuckDuckGo
# --------------------
# /wiki/Optical_disc
# --------------------
# /wiki/SOS_Children%27s_Villages_UK
# --------------------
# /wiki/National_Curriculum_(UK)
# --------------------
# /wiki/Print_on_demand
# --------------------
# /wiki/Books_LLC
# --------------------
# /wiki/Mauritius
# --------------------
# /wiki/VDM_Publishing
# --------------------
# /wiki/DBpedia
# --------------------
# /wiki/Wikidata
# --------------------
# /wiki/Semantic_Web
# --------------------
# /wiki/Resource_Description_Framework
# --------------------
# /wiki/Web_crawler
# --------------------
# /wiki/Wikipedia:Database_download
# --------------------
# /wiki/Journal_of_Documentation
# --------------------
# /wiki/Reference_desk
# --------------------
# /wiki/Help:Mobile_access
# --------------------
# /wiki/File:Wikipedia_on_Mobile_screenshot_2019.png
# --------------------
# /wiki/Web_browser
# --------------------
# /wiki/Internet_access
# --------------------
# /wiki/Mobile_web
# --------------------
# /wiki/Erik_M%C3%B6ller
# --------------------
# /wiki/Bloomberg_Businessweek
# --------------------
# /wiki/Wireless_Application_Protocol
# --------------------
# /wiki/IPhone
# --------------------
# /wiki/WebOS
# --------------------
# /wiki/Metadata
# --------------------
# /wiki/Geographic_data_and_information
# --------------------
# /wiki/Wikipedia_Zero
# --------------------
# /wiki/Andrew_Brown_(writer)
# --------------------
# /wiki/Smartphone
# --------------------
# /wiki/Wikipedian
# --------------------
# /wiki/Status_quo
# --------------------
# /wiki/Internet_censorship_in_China
# --------------------
# /wiki/Mainland_China
# --------------------
# /wiki/HTTPS
# --------------------
# /wiki/Quartz_(publication)
# --------------------
# /wiki/State_Council_of_the_People%27s_Republic_of_China
# --------------------
# /wiki/Noam_Cohen
# --------------------
# /wiki/Logistic_function
# --------------------
# /wiki/Pew_Research_Center
# --------------------
# /wiki/COVID-19_pandemic
# --------------------
# /wiki/Wikipedia:Wikipedia_in_webcomics
# --------------------
# /wiki/File:Wikipedia_Monument_in_S%C5%82ubice_-_detail.JPG
# --------------------
# /wiki/S%C5%82ubice
# --------------------
# /wiki/Mihran_Hakobyan
# --------------------
# /wiki/Parliament_of_Canada
# --------------------
# /wiki/Same-sex_marriage
# --------------------
# /wiki/Civil_Marriage_Act
# --------------------
# /wiki/World_Intellectual_Property_Organization
# --------------------
# /wiki/United_States_Intelligence_Community
# --------------------
# /wiki/RNA_Biology
# --------------------
# /wiki/Rfam
# --------------------
# /wiki/Plagiarism_from_Wikipedia
# --------------------
# /wiki/Reddit
# --------------------
# /wiki/MySpace
# --------------------
# /wiki/BBC_Radio_4
# --------------------
# /wiki/Italy
# --------------------
# /wiki/Franco_Grillini
# --------------------
# /wiki/Freedom_of_panorama
# --------------------
# /wiki/File:Wikipedia,_an_introduction_-_Erasmus_Prize_2015.webm
# --------------------
# /wiki/Erasmus_Prize
# --------------------
# /wiki/File:Quadriga-verleihung-rr-02.jpg
# --------------------
# /wiki/Quadriga_(award)
# --------------------
# /wiki/The_Washington_Post
# --------------------
# /wiki/2008_United_States_presidential_election
# --------------------
# /wiki/Reuters
# --------------------
# /wiki/Peter_Stone_(professor)
# --------------------
# /wiki/Stanford
# --------------------
# /wiki/One_Hundred_Year_Study_on_Artificial_Intelligence
# --------------------
# /wiki/Wired_(magazine)
# --------------------
# /wiki/Hossein_Derakhshan
# --------------------
# /wiki/Openness
# --------------------
# /wiki/Decentralization#Centralization_and_redecentralization_of_the_Internet
# --------------------
# /wiki/Social_media
# --------------------
# /wiki/Social_networking_service
# --------------------
# /wiki/Age_of_Enlightenment
# --------------------
# /wiki/Rationality
# --------------------
# /wiki/Typography
# --------------------
# /wiki/Sapere_aude
# --------------------
# /wiki/Literal_translation
# --------------------
# /wiki/File:Wikipedia_team_visiting_to_Parliament_of_Oviedo_Spain_2015.JPG
# --------------------
# /wiki/File:Spanish_Wikipedians_meetup.jpg
# --------------------
# /wiki/Prix_Ars_Electronica
# --------------------
# /wiki/Webby_Award
# --------------------
# /wiki/Boris_Tadi%C4%87
# --------------------
# /wiki/Eckart_H%C3%B6fling
# --------------------
# /wiki/Peter_Gabriel
# --------------------
# /wiki/David_Weinberger
# --------------------
# /wiki/Spain
# --------------------
# /wiki/Princess_of_Asturias_Award
# --------------------
# /wiki/Asturian_language
# --------------------
# /wiki/Category:Parodies_of_Wikipedia
# --------------------
# /wiki/Wikiality
# --------------------
# /wiki/The_Onion
# --------------------
# /wiki/The_Office_(American_TV_series)
# --------------------
# /wiki/Michael_Scott_(The_Office)
# --------------------
# /wiki/Negotiation
# --------------------
# /wiki/My_Number_One_Doctor
# --------------------
# /wiki/Scrubs_(TV_series)
# --------------------
# /wiki/Perry_Cox
# --------------------
# /wiki/Raw_food_diet
# --------------------
# /wiki/Bone_cancer
# --------------------
# /wiki/List_of_Battlestar_Galactica_(2004_TV_series)_episodes
# --------------------
# /wiki/CollegeHumor
# --------------------
# /wiki/Dilbert
# --------------------
# /wiki/Bigipedia
# --------------------
# /wiki/The_New_Yorker
# --------------------
# /wiki/Chelsea_Manning
# --------------------
# /wiki/Trans_woman
# --------------------
# /wiki/John_Julius_Norwich
# --------------------
# /wiki/The_Times
# --------------------
# /wiki/Wikimedia_projects
# --------------------
# /wiki/Wikiquote
# --------------------
# /wiki/Wikinews
# --------------------
# /wiki/Wikiversity
# --------------------
# /wiki/Wikispecies
# --------------------
# /wiki/Wikivoyage
# --------------------
# /wiki/File:WikiMedia_DC_2013_Annual_Meeting_08.JPG
# --------------------
# /wiki/Wikimedia_DC
# --------------------
# /wiki/Nicholas_G._Carr
# --------------------
# /wiki/Web_2.0
# --------------------
# /wiki/User-generated_content
# --------------------
# /wiki/Chris_Anderson_(writer)
# --------------------
# /wiki/Nature_(journal)
# --------------------
# /wiki/Wisdom_of_the_crowd
# --------------------
# /wiki/Scientific_journal
# --------------------
# /wiki/Peer_review
# --------------------
# /wiki/Kathryn_Hughes
# --------------------
# /wiki/Text_corpus
# --------------------
# /wiki/Computational_linguistics
# --------------------
# /wiki/Information_retrieval
# --------------------
# /wiki/Natural_language_processing
# --------------------
# /wiki/Entity_linking
# --------------------
# /wiki/Word-sense_disambiguation
# --------------------
# /wiki/University_of_Franche-Comt%C3%A9
# --------------------
# /wiki/Besan%C3%A7on
# --------------------
# /wiki/Paul_Sabatier_University
# --------------------
# /wiki/Toulouse
# --------------------
# /wiki/PageRank
# --------------------
# /wiki/CheiRank
# --------------------
# /wiki/MIT
# --------------------
# /wiki/Machine_learning
# --------------------
# /wiki/Artificial_intelligence
# --------------------
# /wiki/Data_quality
# --------------------
# /wiki/Civil_Service_(United_Kingdom)
# --------------------
# /wiki/Department_for_Levelling_Up,_Housing_and_Communities
# --------------------
# /wiki/Levelling_up_policy_of_the_Boris_Johnson_government
# --------------------
# /wiki/Levelling_Up_White_Paper
# --------------------
# /wiki/The_Independent
# --------------------
# /wiki/White_paper#In_government
# --------------------
# /wiki/Constantinople
# --------------------
# /wiki/List_of_largest_cities_throughout_history
# --------------------
# /wiki/BBC_Domesday_Project
# --------------------
# /wiki/BBC_Micro
# --------------------
# /wiki/Everything2
# --------------------
# /wiki/GNE_(encyclopedia)
# --------------------
# /wiki/H2g2
# --------------------
# /wiki/Douglas_Adams
# --------------------
# /wiki/Knowledge_base
# --------------------
# /wiki/Susning.nu
# --------------------
# /wiki/Hudong
# --------------------
# /wiki/Baidu_Baike
# --------------------
# /wiki/Conservapedia
# --------------------
# /wiki/Wikipedia:Citation_needed
# --------------------
# /wiki/Encyclopedia_of_Life
# --------------------
# /wiki/Scholarpedia
# --------------------
# /wiki/Citizendium
# --------------------
# /wiki/Category:Wikipedia
# --------------------
# /wiki/File:Crystal_Clear_app_linneighborhood.svg
# --------------------
# /wiki/Portal:Internet
# --------------------
# /wiki/Portal:Wikipedia
# --------------------
# /wiki/Interpedia
# --------------------
# /wiki/Internet
# --------------------
# /wiki/List_of_online_encyclopedias
# --------------------
# /wiki/List_of_Wikipedia_controversies
# --------------------
# /wiki/Network_effect
# --------------------
# /wiki/Outline_of_Wikipedia
# --------------------
# /wiki/Tree_structure
# --------------------
# /wiki/Portal:Contents/Outlines
# --------------------
# /wiki/QRpedia
# --------------------
# /wiki/Wikipedia_Review
# --------------------
# /wiki/Recursion
# --------------------
# /wiki/Wikipedia:Biographies_of_living_persons/Noticeboard
# --------------------
# /wiki/Wikipedia:Neutral_point_of_view/Noticeboard
# --------------------
# /wiki/U-T_San_Diego
# --------------------
# /wiki/Salt_Lake_City_Weekly
# --------------------
# /wiki/The_San_Diego_Union-Tribune
# --------------------
# /wiki/The_Wall_Street_Journal
# --------------------
# /wiki/Slate_(magazine)
# --------------------
# /wiki/Ned_Kock
# --------------------
# /wiki/International_Journal_of_e-Collaboration
# --------------------
# /wiki/Doi_(identifier)
# --------------------
# /wiki/ISSN_(identifier)
# --------------------
# /wiki/Wikipedia:Neutral_point_of_view
# --------------------
# /wiki/ISBN_(identifier)
# --------------------
# /wiki/Special:BookSources/978-1594201530
# --------------------
# /wiki/Wikimedia
# --------------------
# /wiki/Wikipedia:Modelling_Wikipedia_extended_growth
# --------------------
# /wiki/Template:Cite_journal
# --------------------
# /wiki/Help:CS1_errors#missing_periodical
# --------------------
# /wiki/Open_access
# --------------------
# /wiki/S2CID_(identifier)
# --------------------
# /wiki/Vox_(website)
# --------------------
# /wiki/CNET
# --------------------
# /wiki/Jonathan_Zittrain
# --------------------
# /wiki/Special:BookSources/978-0300124873
# --------------------
# /wiki/Wikipedia:Tutorial/Registration
# --------------------
# /wiki/Wikipedia:Protection_policy
# --------------------
# /wiki/Wikipedia:Full_protection
# --------------------
# /wiki/Wikipedia:New_pages_patrol
# --------------------
# /wiki/Special:BookSources/9781450307888
# --------------------
# /wiki/Wikipedia:Vandalism
# --------------------
# /wiki/Special:BookSources/978-1581137026
# --------------------
# /wiki/CiteSeerX_(identifier)
# --------------------
# /wiki/Farrar,_Straus_%26_Giroux
# --------------------
# /wiki/Special:BookSources/978-0374292782
# --------------------
# /wiki/BusinessWeek
# --------------------
# /wiki/Wikipedia:Dispute_Resolution
# --------------------
# /wiki/NBC_News
# --------------------
# /wiki/Special:BookSources/978-1467397438
# --------------------
# /wiki/Special:BookSources/978-1605587301
# --------------------
# /wiki/Wikipedia:What_Wikipedia_is_not
# --------------------
# /wiki/Wikipedia:Notability
# --------------------
# /wiki/Wikipedia:No_original_research
# --------------------
# /wiki/Wikipedia:Verifiability
# --------------------
# /wiki/International_Herald_Tribune
# --------------------
# /wiki/Wikipedia:Ownership_of_articles
# --------------------
# /wiki/Wikipedia:Administrators
# --------------------
# /wiki/Dariusz_Jemielniak
# --------------------
# /wiki/Stanford_University_Press
# --------------------
# /wiki/Special:BookSources/978-0804791205
# --------------------
# /wiki/SSRN_(identifier)
# --------------------
# /wiki/Emory_Law_Journal
# --------------------
# /wiki/Fernanda_B._Vi%C3%A9gas
# --------------------
# /wiki/Martin_M._Wattenberg
# --------------------
# /wiki/IBM_Research
# --------------------
# /wiki/Kuro5hin
# --------------------
# /wiki/Special:BookSources/978-1605580074
# --------------------
# /wiki/PMID_(identifier)
# --------------------
# /wiki/Bloomberg_News
# --------------------
# /wiki/J%C3%A1nos_Kert%C3%A9sz
# --------------------
# /wiki/ArXiv_(identifier)
# --------------------
# /wiki/Bibcode_(identifier)
# --------------------
# /wiki/PMC_(identifier)
# --------------------
# /wiki/History_News_Network
# --------------------
# /wiki/Columbian_College_of_Arts_and_Sciences
# --------------------
# /wiki/Elsevier
# --------------------
# /wiki/Bowling_Green_State_University
# --------------------
# /wiki/Hoover_Institution
# --------------------
# /wiki/MIT_Press
# --------------------
# /wiki/Special:BookSources/978-0262360593
# --------------------
# /wiki/Jim_Giles_(reporter)
# --------------------
# /wiki/The_Register
# --------------------
# /wiki/PC_World
# --------------------
# /wiki/PCMag
# --------------------
# /wiki/Stacy_Schiff
# --------------------
# /wiki/Blog
# --------------------
# /wiki/University_of_California,_Berkeley
# --------------------
# /wiki/Berkman_Center_for_Internet_%26_Society
# --------------------
# /wiki/Harvard_Law_School
# --------------------
# /wiki/TCS_Daily
# --------------------
# /wiki/Brian_Bergstein
# --------------------
# /wiki/Special:BookSources/978-0314264084
# --------------------
# /wiki/Wayback_Machine
# --------------------
# /wiki/Wikipedia:PAPER
# --------------------
# /wiki/Ed_Chi
# --------------------
# /wiki/Special:BookSources/978-1605582467
# --------------------
# /wiki/Massachusetts_Institute_of_Technology
# --------------------
# /wiki/Special:BookSources/978-1450322638
# --------------------
# /wiki/Template:Cite_news
# --------------------
# /wiki/Category:CS1_maint:_unfit_URL
# --------------------
# /wiki/Peter_Lang_(publisher)
# --------------------
# /wiki/Special:BookSources/978-1454191636
# --------------------
# /wiki/Heinz_Heise
# --------------------
# /wiki/Springer_Science%2BBusiness_Media
# --------------------
# /wiki/Softpedia
# --------------------
# /wiki/Wikipedia:Bots
# --------------------
# /wiki/Wikipedia:Bot_policy
# --------------------
# /wiki/The_Wikipedia_Revolution
# --------------------
# /wiki/Frederic_M._Scherer
# --------------------
# /wiki/University_of_Illinois_at_Urbana%E2%80%93Champaign
# --------------------
# /wiki/Wikipedia:Copyrights
# --------------------
# /wiki/Wikipedia:Wikipedia_CD_Selection
# --------------------
# /wiki/Frankfurter_Allgemeine_Zeitung
# --------------------
# /wiki/Meta-Wiki
# --------------------
# /wiki/Bloomberg_BusinessWeek
# --------------------
# /wiki/San_Antonio_Express-News
# --------------------
# /wiki/Cond%C3%A9_Nast
# --------------------
# /wiki/EISSN_(identifier)
# --------------------
# /wiki/Wikipedia:Meta
# --------------------
# /wiki/American_Broadcasting_Company
# --------------------
# /wiki/British_Comedy_Guide
# --------------------
# /wiki/Emily_Flake
# --------------------
# /wiki/Wikipedia:Link_rot
# --------------------
# /wiki/Christopher_Caldwell_(journalist)
# --------------------
# /wiki/Financial_Times
# --------------------
# /wiki/Rada_Mihalcea
# --------------------
# /wiki/Conference_on_Information_and_Knowledge_Management
# --------------------
# /wiki/Association_for_Computing_Machinery
# --------------------
# /wiki/Special:BookSources/978-1595938039
# --------------------
# /wiki/Ian_H._Witten
# --------------------
# /wiki/Special:BookSources/978-1595939913
# --------------------
# /wiki/Maarten_de_Rijke
# --------------------
# /wiki/Special:BookSources/978-1595931351
# --------------------
# /wiki/Template:Cite_conference
# --------------------
# /wiki/Help:CS1_errors#archive_missing_url
# --------------------
# /wiki/MarketWatch
# --------------------
# /wiki/Times_Higher_Education
# --------------------
# /wiki/Aaron_Halfaker
# --------------------
# /wiki/Special:BookSources/978-1450349147
# --------------------
# /wiki/ECIR
# --------------------
# /wiki/Special:BookSources/978-3540786450
# --------------------
# /wiki/Cliff_Lampe
# --------------------
# /wiki/Andrew_Orlowski
# --------------------
# /wiki/Special:BookSources/978-1421415352
# --------------------
# /wiki/First_Monday_(journal)
# --------------------
# /wiki/Loren_Terveen
# --------------------
# /wiki/John_Riedl
# --------------------
# /wiki/Special:BookSources/978-1595938459
# --------------------
# /wiki/Hdl_(identifier)
# --------------------
# /wiki/Special:BookSources/978-9402813715
# --------------------
# /wiki/Roy_Rosenzweig
# --------------------
# /wiki/The_Journal_of_American_History
# --------------------
# /wiki/John_Willinsky
# --------------------
# /wiki/PLOS
# --------------------
# /wiki/List_of_books_about_Wikipedia
# --------------------
# /wiki/Andrew_Keen
# --------------------
# /wiki/The_Cult_of_the_Amateur
# --------------------
# /wiki/Special:BookSources/978-0385520805
# --------------------
# /wiki/Special:BookSources/978-1593271763
# --------------------
# /wiki/Wikipedia_%E2%80%93_The_Missing_Manual
# --------------------
# /wiki/Special:BookSources/978-0596515164
# --------------------
# /wiki/Special:BookSources/978-0596521745
# --------------------
# /wiki/Sheizaf_Rafaeli
# --------------------
# /wiki/Cambridge_University_Press
# --------------------
# /wiki/Special:BookSources/978-0521694643
# --------------------
# /wiki/Andrew_Dalby
# --------------------
# /wiki/Special:BookSources/978-0956205209
# --------------------
# /wiki/The_Wikipedia_Revolution:_How_a_Bunch_of_Nobodies_Created_the_World%27s_Greatest_Encyclopedia
# --------------------
# /wiki/Special:BookSources/978-1401303716
# --------------------
# /wiki/Special:BookSources/978-0754674337
# --------------------
# /wiki/Special:BookSources/978-0262014472
# --------------------
# /wiki/Common_Knowledge%3F_An_Ethnography_of_Wikipedia
# --------------------
# /wiki/Special:BookSources/978-0804789448
# --------------------
# /wiki/Special:BookSources/978-0262538176
# --------------------
# /wiki/Nicholson_Baker
# --------------------
# /wiki/The_New_York_Review_of_Books
# --------------------
# /wiki/L._Gordon_Crovitz
# --------------------
# /wiki/Virginia_Postrel
# --------------------
# /wiki/Pacific_Standard
# --------------------
# /wiki/Web_conferencing
# --------------------
# /wiki/Ideas_(radio_show)
# --------------------
# /wiki/CBC_Radio_One
# --------------------
# /wiki/Kat_Walsh
# --------------------
# /wiki/Houston_Chronicle
# --------------------
# /wiki/New_Scientist
# --------------------
# /wiki/The_Phoenix_(newspaper)
# --------------------
# /wiki/Marshall_Poe
# --------------------
# /wiki/Library_of_Congress
# --------------------
# /wiki/Media_in_New_York%27s_Capital_District
# --------------------
# /wiki/Vice_(magazine)
# --------------------
# /wiki/Full_Measure_with_Sharyl_Attkisson
# --------------------
# /wiki/Cato_Institute
# --------------------
# /wiki/Wikipedia:Wikimedia_sister_projects
# --------------------
# /wiki/Curlie
# --------------------
# /wiki/Twitter
# --------------------
# /wiki/Template:Wikipedia
# --------------------
# /wiki/Template_talk:Wikipedia
# --------------------
# /wiki/Citation_needed_(Wikipedia)
# --------------------
# /wiki/Geographical_bias_on_Wikipedia
# --------------------
# /wiki/Racial_bias_on_Wikipedia
# --------------------
# /wiki/Edit_count
# --------------------
# /wiki/Ignore_all_rules
# --------------------
# /wiki/Predictions_of_the_end_of_Wikipedia
# --------------------
# /wiki/AfroCrowd
# --------------------
# /wiki/Art%2BFeminism
# --------------------
# /wiki/The_Signpost
# --------------------
# /wiki/Wiki_Indaba
# --------------------
# /wiki/Wiki_Loves_Monuments
# --------------------
# /wiki/Wiki_Loves_Pride
# --------------------
# /wiki/Wiki_Loves_Earth
# --------------------
# /wiki/Wiki_Loves_Folklore
# --------------------
# /wiki/Wiki_Conference_India
# --------------------
# /wiki/WikiConference_North_America
# --------------------
# /wiki/Wikimania
# --------------------
# /wiki/Wikipedian_in_residence
# --------------------
# /wiki/WikiProject
# --------------------
# /wiki/Women_in_Red
# --------------------
# /wiki/List_of_Wikipedia_people
# --------------------
# /wiki/Florence_Devouard
# --------------------
# /wiki/Maryana_Iskander
# --------------------
# /wiki/Ira_Brad_Matetsky
# --------------------
# /wiki/Steven_Pruitt
# --------------------
# /wiki/Mar%C3%ADa_Sefidari
# --------------------
# /wiki/Wikimedian_of_the_Year
# --------------------
# /wiki/First_Wikipedia_edit
# --------------------
# /wiki/United_States_Congressional_staff_edits_to_Wikipedia
# --------------------
# /wiki/Essjay_controversy
# --------------------
# /wiki/Wikipedia_Seigenthaler_biography_incident
# --------------------
# /wiki/Henryk_Batuta_hoax
# --------------------
# /wiki/Jar%27Edo_Wens_hoax
# --------------------
# /wiki/Croatian_Wikipedia#Controversy_about_right-wing_bias
# --------------------
# /wiki/Church_of_Scientology_editing_on_Wikipedia
# --------------------
# /wiki/Committee_for_Accuracy_in_Middle_East_Reporting_in_America#CAMERA_campaign_at_Wikipedia
# --------------------
# /wiki/Italian_Wikipedia#2011_mass_blanking_protest
# --------------------
# /wiki/Protests_against_SOPA_and_PIPA#Wikimedia_community
# --------------------
# /wiki/Hillsborough_disaster_Wikipedia_posts
# --------------------
# /wiki/MyWikiBiz
# --------------------
# /wiki/1Lib1Ref
# --------------------
# /wiki/Wikipedia_Star_Trek_Into_Darkness_controversy
# --------------------
# /wiki/2021_Wikimedia_Foundation_actions_on_the_Chinese_Wikipedia
# --------------------
# /wiki/Wikipedia_and_the_2022_Russian_invasion_of_Ukraine
# --------------------
# /wiki/Princess_of_Asturias_Awards
# --------------------
# /wiki/Listen_to_Wikipedia
# --------------------
# /wiki/Wiki-Watch
# --------------------
# /wiki/WikiScanner
# --------------------
# /wiki/List_of_Wikipedia_mobile_applications
# --------------------
# /wiki/WikiNodes
# --------------------
# /wiki/Wikiwand
# --------------------
# /wiki/Boundless_(company)
# --------------------
# /wiki/Deletionpedia
# --------------------
# /wiki/Kiwix
# --------------------
# /wiki/Wikimedia_Enterprise
# --------------------
# /wiki/WikiReader
# --------------------
# /wiki/Science_information_on_Wikipedia
# --------------------
# /wiki/Everipedia
# --------------------
# /wiki/Veropedia
# --------------------
# /wiki/List_of_wikis
# --------------------
# /wiki/The_Iraq_War:_A_Historiography_of_Wikipedia_Changelogs
# --------------------
# /wiki/Magna_Carta_(An_Embroidery)
# --------------------
# /wiki/Wiki_rabbit_hole
# --------------------
# /wiki/Wikiracing
# --------------------
# /wiki/Wikipedia_for_World_Heritage
# --------------------
# /wiki/Wikimedia_movement
# --------------------
# /wiki/Template:Wikipedias
# --------------------
# /wiki/Template_talk:Wikipedias
# --------------------
# /wiki/Hungarian_Wikipedia
# --------------------
# /wiki/Czech_Wikipedia
# --------------------
# /wiki/Serbo-Croatian_Wikipedia
# --------------------
# /wiki/Chechen_Wikipedia
# --------------------
# /wiki/Romanian_Wikipedia
# --------------------
# /wiki/Southern_Min_Wikipedia
# --------------------
# /wiki/Tatar_Wikipedia
# --------------------
# /wiki/Basque_Wikipedia
# --------------------
# /wiki/Malay_Wikipedia
# --------------------
# /wiki/Esperanto_Wikipedia
# --------------------
# /wiki/Hebrew_Wikipedia
# --------------------
# /wiki/Armenian_Wikipedia
# --------------------
# /wiki/Bulgarian_Wikipedia
# --------------------
# /wiki/Danish_Wikipedia
# --------------------
# /wiki/South_Azerbaijani_Wikipedia
# --------------------
# /wiki/Slovak_Wikipedia
# --------------------
# /wiki/Kazakh_Wikipedia
# --------------------
# /wiki/Minangkabau_Wikipedia
# --------------------
# /wiki/Estonian_Wikipedia
# --------------------
# /wiki/Belarusian_Wikipedia
# --------------------
# /wiki/Croatian_Wikipedia
# --------------------
# /wiki/Greek_Wikipedia
# --------------------
# /wiki/Lithuanian_Wikipedia
# --------------------
# /wiki/Galician_Wikipedia
# --------------------
# /wiki/Azerbaijani_Wikipedia
# --------------------
# /wiki/Slovene_Wikipedia
# --------------------
# /wiki/Urdu_Wikipedia
# --------------------
# /wiki/Georgian_Wikipedia
# --------------------
# /wiki/Hindi_Wikipedia
# --------------------
# /wiki/Uzbek_Wikipedia
# --------------------
# /wiki/Thai_Wikipedia
# --------------------
# /wiki/Tamil_Wikipedia
# --------------------
# /wiki/Latin_Wikipedia
# --------------------
# /wiki/Welsh_Wikipedia
# --------------------
# /wiki/Asturian_Wikipedia
# --------------------
# /wiki/Macedonian_Wikipedia
# --------------------
# /wiki/Cantonese_Wikipedia
# --------------------
# /wiki/Bengali_Wikipedia
# --------------------
# /wiki/Volap%C3%BCk_Wikipedia
# --------------------
# /wiki/Latvian_Wikipedia
# --------------------
# /wiki/Tajik_Wikipedia
# --------------------
# /wiki/Afrikaans_Wikipedia
# --------------------
# /wiki/Burmese_Wikipedia
# --------------------
# /wiki/Occitan_Wikipedia
# --------------------
# /wiki/Bosnian_Wikipedia
# --------------------
# /wiki/Albanian_Wikipedia
# --------------------
# /wiki/Kyrgyz_Wikipedia
# --------------------
# /wiki/Malayalam_Wikipedia
# --------------------
# /wiki/Marathi_Wikipedia
# --------------------
# /wiki/Telugu_Wikipedia
# --------------------
# /wiki/Breton_Wikipedia
# --------------------
# /wiki/Javanese_Wikipedia
# --------------------
# /wiki/Punjabi_Wikipedia_(Western)
# --------------------
# /wiki/Swahili_Wikipedia
# --------------------
# /wiki/Luxembourgish_Wikipedia
# --------------------
# /wiki/Tagalog_Wikipedia
# --------------------
# /wiki/Irish_Wikipedia
# --------------------
# /wiki/Ladin_Wikipedia
# --------------------
# /wiki/Silesian_Wikipedia
# --------------------
# /wiki/Kurmanji_Kurdish_Wikipedia
# --------------------
# /wiki/Chuvash_Wikipedia
# --------------------
# /wiki/Aragonese_Wikipedia
# --------------------
# /wiki/Punjabi_Wikipedia
# --------------------
# /wiki/Nepali_Wikipedia
# --------------------
# /wiki/Sorani_Kurdish_Wikipedia
# --------------------
# /wiki/Alemannic_Wikipedia
# --------------------
# /wiki/Kannada_Wikipedia
# --------------------
# /wiki/Scots_Wikipedia
# --------------------
# /wiki/Mongolian_Wikipedia
# --------------------
# /wiki/Samogitian_Wikipedia
# --------------------
# /wiki/Odia_Wikipedia
# --------------------
# /wiki/Scottish_Gaelic_Wikipedia
# --------------------
# /wiki/Yiddish_Wikipedia
# --------------------
# /wiki/Sindhi_Wikipedia
# --------------------
# /wiki/Maithili_Wikipedia
# --------------------
# /wiki/Ossetian_Wikipedia
# --------------------
# /wiki/Sanskrit_Wikipedia
# --------------------
# /wiki/Gorontalo_Wikipedia
# --------------------
# /wiki/Balinese_Wikipedia
# --------------------
# /wiki/Zulu_Wikipedia
# --------------------
# /wiki/Emilian-Romagnol_Wikipedia
# --------------------
# /wiki/Northern_Sami_Wikipedia
# --------------------
# /wiki/Crimean_Tatar_Wikipedia
# --------------------
# /wiki/Bhojpuri_Wikipedia
# --------------------
# /wiki/Assamese_Wikipedia
# --------------------
# /wiki/Dutch_Low_Saxon_Wikipedia
# --------------------
# /wiki/Guarani_Wikipedia
# --------------------
# /wiki/Konkani_Wikipedia
# --------------------
# /wiki/Judaeo-Spanish_Wikipedia
# --------------------
# /wiki/Extremaduran_Wikipedia
# --------------------
# /wiki/Santali_Wikipedia
# --------------------
# /wiki/Ripuarian_Wikipedia
# --------------------
# /wiki/Wolof_Wikipedia
# --------------------
# /wiki/Tulu_Wikipedia
# --------------------
# /wiki/Xhosa_Wikipedia
# --------------------
# /wiki/Kashmiri_Wikipedia
# --------------------
# /wiki/Bambara_Wikipedia
# --------------------
# /wiki/Template:Wikimedia_Foundation
# --------------------
# /wiki/Template_talk:Wikimedia_Foundation
# --------------------
# /wiki/Rebecca_MacKinnon
# --------------------
# /wiki/Raju_Narisetti
# --------------------
# /wiki/Rosie_Stephenson-Goodknight
# --------------------
# /wiki/Esra%27a_Al_Shafei
# --------------------
# /wiki/Hampton_Catlin
# --------------------
# /wiki/Danese_Cooper
# --------------------
# /wiki/Bishakha_Datta
# --------------------
# /wiki/Oscar_van_Dillen
# --------------------
# /wiki/Arnnon_Geshuri
# --------------------
# /wiki/Mike_Godwin
# --------------------
# /wiki/Guy_Kawasaki
# --------------------
# /wiki/Patricio_Lorente
# --------------------
# /wiki/Luis_Villa
# --------------------
# /wiki/List_of_Wiktionaries
# --------------------
# /wiki/Wikisource
# --------------------
# /wiki/Wikifunctions
# --------------------
# /wiki/Litigation_involving_the_Wikimedia_Foundation
# --------------------
# /wiki/G_%26_G_v_Wikimedia_Foundation_Inc
# --------------------
# /wiki/Wikimedia_Foundation_v._NSA
# ...
# --------------------
# /wiki/Paris_Agreement
# --------------------
# /wiki/Hispanic_Society_of_America
# --------------------
# /wiki/Amref_Health_Africa
# --------------------
# /wiki/Sal_Khan
# --------------------
# /wiki/Khan_Academy
# --------------------
# /wiki/GAVI
# --------------------
# /wiki/Camfed
# --------------------
# /wiki/Ellen_MacArthur
# --------------------
# /wiki/Help:Authority_control
# --------------------
# /wiki/ISNI_(identifier)
# --------------------
# /wiki/VIAF_(identifier)
# --------------------
# /wiki/SUDOC_(identifier)
# --------------------
# /wiki/Help:Category
# --------------------
# /wiki/Category:2001_establishments_in_the_United_States
# --------------------
# /wiki/Category:Advertising-free_websites
# --------------------
# /wiki/Category:Creative_Commons-licensed_websites
# --------------------
# /wiki/Category:Free-content_websites
# --------------------
# /wiki/Category:Internet_properties_established_in_2001
# --------------------
# /wiki/Category:Jimmy_Wales
# --------------------
# /wiki/Category:Multilingual_websites
# --------------------
# /wiki/Category:Online_encyclopedias
# --------------------
# /wiki/Category:Social_information_processing
# --------------------
# /wiki/Category:Wikimedia_projects
# --------------------
# /wiki/Category:Pages_using_the_Graph_extension
# --------------------
# /wiki/Category:CS1_errors:_missing_periodical
# --------------------
# /wiki/Category:CS1_German-language_sources_(de)
# --------------------
# /wiki/Category:Pages_containing_links_to_subscription-only_content
# --------------------
# /wiki/Category:Webarchive_template_wayback_links
# --------------------
# /wiki/Category:CS1_Italian-language_sources_(it)
# --------------------
# /wiki/Category:CS1_Spanish-language_sources_(es)
# --------------------
# /wiki/Category:All_articles_with_dead_external_links
# --------------------
# /wiki/Category:Articles_with_dead_external_links_from_February_2022
# --------------------
# /wiki/Category:Articles_with_permanently_dead_external_links
# --------------------
# /wiki/Category:CS1_errors:_archive-url
# --------------------
# /wiki/Category:Articles_with_short_description
# --------------------
# /wiki/Category:Short_description_matches_Wikidata
# --------------------
# /wiki/Category:Wikipedia_pages_semi-protected_against_vandalism
# --------------------
# /wiki/Category:Wikipedia_indefinitely_move-protected_pages
# --------------------
# /wiki/Category:Use_mdy_dates_from_March_2021
# --------------------
# /wiki/Category:Use_American_English_from_June_2019
# --------------------
# /wiki/Category:All_Wikipedia_articles_written_in_American_English
# --------------------
# /wiki/Category:Articles_with_hAudio_microformats
# --------------------
# /wiki/Category:Pages_including_recorded_pronunciations
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2022
# --------------------
# /wiki/Category:All_articles_containing_potentially_dated_statements
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_November_2020
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_January_2019
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_March_2020
# --------------------
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_June_2022
# --------------------
# /wiki/Category:All_Wikipedia_articles_in_need_of_updating
# --------------------
# /wiki/Category:All_articles_with_vague_or_ambiguous_time
# --------------------
# /wiki/Category:Vague_or_ambiguous_time_from_July_2021
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2013
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_January_2021
# --------------------
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_March_2018
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2014
# --------------------
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_December_2020
# --------------------
# /wiki/Category:Wikipedia_articles_needing_clarification_from_December_2020
# --------------------
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_March_2017
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_January_2008
# --------------------
# /wiki/Category:All_Wikipedia_articles_needing_clarification
# --------------------
# /wiki/Category:Wikipedia_articles_needing_clarification_from_August_2019
# --------------------
# /wiki/Category:All_articles_lacking_reliable_references
# --------------------
# /wiki/Category:Articles_lacking_reliable_references_from_June_2022
# --------------------
# /wiki/Category:Interlanguage_link_template_existing_link
# --------------------
# /wiki/Category:Wikipedia_articles_in_need_of_updating_from_July_2019
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2021
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_April_2020
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_December_2009
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_April_2021
# --------------------
# /wiki/Category:Articles_containing_potentially_dated_statements_from_2007
# --------------------
# /wiki/Category:Articles_containing_Latin-language_text
# --------------------
# /wiki/Category:All_articles_with_unsourced_statements
# --------------------
# /wiki/Category:Articles_with_unsourced_statements_from_March_2021
# --------------------
# /wiki/Category:Webarchive_template_other_archives
# --------------------
# /wiki/Category:Pages_using_Sister_project_links_with_hidden_wikidata
# --------------------
# /wiki/Category:Pages_using_Sister_project_links_with_default_search
# --------------------
# /wiki/Category:Articles_with_Curlie_links
# --------------------
# /wiki/Category:Guardian_topic_template_using_Wikidata
# --------------------
# /wiki/Category:Articles_containing_Spanish-language_text
# --------------------
# /wiki/Category:Articles_with_ISNI_identifiers
# --------------------
# /wiki/Category:Articles_with_VIAF_identifiers
# --------------------
# /wiki/Category:Articles_with_WORLDCATID_identifiers
# --------------------
# /wiki/Category:Articles_with_BIBSYS_identifiers
# --------------------
# /wiki/Category:Articles_with_BNF_identifiers
# --------------------
# /wiki/Category:Articles_with_GND_identifiers
# --------------------
# /wiki/Category:Articles_with_J9U_identifiers
# --------------------
# /wiki/Category:Articles_with_LCCN_identifiers
# --------------------
# /wiki/Category:Articles_with_NKC_identifiers
# --------------------
# /wiki/Category:Articles_with_NSK_identifiers
# --------------------
# /wiki/Category:Articles_with_SELIBR_identifiers
# --------------------
# /wiki/Category:Articles_with_FAST_identifiers
# --------------------
# /wiki/Category:Articles_with_SUDOC_identifiers
# --------------------
# /wiki/Category:Articles_with_multiple_identifiers
# --------------------
# /wiki/Category:Articles_containing_video_clips
# --------------------
# /wiki/Special:MyTalk
# --------------------
# /wiki/Special:MyContributions
# --------------------
# /wiki/Talk:Wikipedia
# --------------------
# /wiki/Wikipedia:Contents
# --------------------
# /wiki/Portal:Current_events
# --------------------
# /wiki/Special:Random
# --------------------
# /wiki/Wikipedia:About
# --------------------
# /wiki/Help:Contents
# --------------------
# /wiki/Help:Introduction
# --------------------
# /wiki/Wikipedia:Community_portal
# --------------------
# /wiki/Special:RecentChanges
# --------------------
# /wiki/Wikipedia:File_Upload_Wizard
# --------------------
# /wiki/Special:WhatLinksHere/Wikipedia
# --------------------
# /wiki/Special:RecentChangesLinked/Wikipedia
# --------------------
# /wiki/Special:SpecialPages
# --------------------
# /wiki/Wikipedia:General_disclaimer
# --------------------
# /wiki/Encyclopedia
# --------------------
# /wiki/Help:Introduction_to_Wikipedia
# --------------------
# /wiki/English_language
# --------------------
# /wiki/File:Charles_II_(de_Champaigne).jpg
# --------------------
# /wiki/Anglo-Scottish_war_(1650%E2%80%931652)
# --------------------
# /wiki/Wars_of_the_Three_Kingdoms
# --------------------
# /wiki/First_English_Civil_War
# --------------------
# /wiki/Second_English_Civil_War
# --------------------
# /wiki/Rump_Parliament
# --------------------
# /wiki/Execution_of_Charles_I
# --------------------
# /wiki/Charles_I_of_England
# --------------------
# /wiki/Monarchy_of_the_United_Kingdom#Scottish_monarchy
# --------------------
# /wiki/Parliament_of_Scotland
# --------------------
# /wiki/Charles_II_of_England
# --------------------
# /wiki/Monarchy_of_the_United_Kingdom#Personal_union_and_republican_phase
# --------------------
# /wiki/Oliver_Cromwell
# --------------------
# /wiki/Battle_of_Dunbar_(1650)
# --------------------
# /wiki/Firth_of_Forth
# --------------------
# /wiki/Battle_of_Inverkeithing
# --------------------
# /wiki/Battle_of_Worcester
# --------------------
# /wiki/Commonwealth_of_England
# --------------------
# /wiki/The_Cat_and_the_Canary_(1927_film)
# --------------------
# /wiki/Maurice_Leyland
# --------------------
# /wiki/Battle_of_Halidon_Hill
# --------------------
# /wiki/Wikipedia:Today%27s_featured_article/July_2022
# --------------------
# /wiki/Wikipedia:Featured_articles
# --------------------
# /wiki/Wikipedia:About_Today%27s_featured_article
# --------------------
# /wiki/File:Chiropotes_albinasus.jpg
# --------------------
# /wiki/White-nosed_saki
# --------------------
# /wiki/Soprano
# --------------------
# /wiki/Adalgisa_Gabbi
# --------------------
# /wiki/La_Scala
# --------------------
# /wiki/Die_Meistersinger_von_N%C3%BCrnberg
# --------------------
# /wiki/LGBT_pride
# --------------------
# /wiki/Wrath_Month
# --------------------
# /wiki/Kiyoe_Yoshioka
# --------------------
# /wiki/Ikimonogakari
# --------------------
# /wiki/Eevee
# --------------------
# /wiki/Pok%C3%A9mon_the_Movie:_Genesect_and_the_Legend_Awakened
# --------------------
# /wiki/Lawyering_(book)
# --------------------
# /wiki/Cinderella
# --------------------
# /wiki/Kenny_Motsamai
# --------------------
# /wiki/Mogoeng_Mogoeng
# --------------------
# /wiki/Morris_County_Park_Commission
# --------------------
# /wiki/New_Jersey
# --------------------
# /wiki/Mennen_Arena
# --------------------
# /wiki/Gristmill
# --------------------
# /wiki/STU48
# --------------------
# /wiki/Hana_wa_Dare_no_Mono%3F
# --------------------
# /wiki/Tokyo
# --------------------
# /wiki/Wikipedia:Recent_additions
# --------------------
# /wiki/Help:Your_first_article
# --------------------
# /wiki/Template_talk:Did_you_know
# --------------------
# /wiki/File:Prime_Minister_of_the_Democratic_Socialist_Republic_of_Sri_Lanka,_Mr._Ranil_Wickremesinghe,_at_Hyderabad_House,_in_New_Delhi_on_November_23,_2017.jpg
# --------------------
# /wiki/2022_Sri_Lankan_protests
# --------------------
# /wiki/2019%E2%80%93present_Sri_Lankan_economic_crisis
# --------------------
# /wiki/Ranil_Wickremesinghe
# --------------------
# /wiki/2022_Sri_Lankan_presidential_election
# --------------------
# /wiki/President_of_Sri_Lanka
# --------------------
# /wiki/Parliament_of_Sri_Lanka
# --------------------
# /wiki/2022_European_heat_waves
# --------------------
# /wiki/Europe
# --------------------
# /wiki/NASA
# --------------------
# /wiki/Webb%27s_First_Deep_Field
# --------------------
# /wiki/James_Webb_Space_Telescope
# --------------------
# /wiki/Jos%C3%A9_Eduardo_dos_Santos
# --------------------
# /wiki/Shinzo_Abe
# --------------------
# /wiki/Assassination_of_Shinzo_Abe
# --------------------
# /wiki/Nara,_Nara
# --------------------
# /wiki/2022_Russian_invasion_of_Ukraine
# --------------------
# /wiki/Deaths_in_2022
# --------------------
# /wiki/Uwe_Seeler
# --------------------
# /wiki/Ruslana_Pysanka
# --------------------
# /wiki/%C3%81ngela_Ab%C3%B3s_Ballar%C3%ADn
# --------------------
# /wiki/Larry_Jeffrey
# --------------------
# /wiki/Patrick_Michaels
# --------------------
# /wiki/Jos%C3%A9_Ram%C3%B3n_Balaguer
# --------------------
# /wiki/Wikipedia:In_the_news/Candidates
# --------------------
# /wiki/July_22
# --------------------
# /wiki/Pi_Day
# --------------------
# /wiki/File:Emperor_Gia_Long.jpg
# --------------------
# /wiki/838
# --------------------
# /wiki/Arab%E2%80%93Byzantine_wars
# --------------------
# /wiki/Abbasid_Caliphate
# --------------------
# /wiki/Byzantine_Empire
# --------------------
# /wiki/Theophilos_(emperor)
# --------------------
# /wiki/Battle_of_Anzen
# --------------------
# /wiki/1209
# --------------------
# /wiki/B%C3%A9ziers
# --------------------
# /wiki/Massacre_at_B%C3%A9ziers
# --------------------
# /wiki/Albigensian_Crusade
# --------------------
# /wiki/1691
# --------------------
# /wiki/Williamite
# --------------------
# /wiki/Jacobitism
# --------------------
# /wiki/Battle_of_Aughrim
# --------------------
# /wiki/Williamite_War_in_Ireland
# --------------------
# /wiki/1802
# --------------------
# /wiki/Gia_Long
# --------------------
# /wiki/Hanoi
# --------------------
# /wiki/1997
# --------------------
# /wiki/Eiichiro_Oda
# --------------------
# /wiki/One_Piece
# --------------------
# /wiki/List_of_best-selling_manga
# --------------------
# /wiki/Weekly_Sh%C5%8Dnen_Jump
# --------------------
# /wiki/Emma_Lazarus
# --------------------
# /wiki/Selena_Gomez
# --------------------
# /wiki/George_Armitage_Miller
# --------------------
# /wiki/July_21
# --------------------
# /wiki/July_23
# --------------------
# /wiki/Wikipedia:Selected_anniversaries/July
# --------------------
# /wiki/List_of_days_of_the_year
# --------------------
# /wiki/File:Robin_Williams_2011a_(2).jpg
# --------------------
# /wiki/Robin_Williams
# --------------------
# /wiki/List_of_Robin_Williams_performances
# --------------------
# /wiki/Can_I_Do_It..._%27Til_I_Need_Glasses%3F
# --------------------
# /wiki/The_Richard_Pryor_Show
# --------------------
# /wiki/Rowan_%26_Martin%27s_Laugh-In
# --------------------
# /wiki/Mork_%26_Mindy
# --------------------
# /wiki/Happy_Days
# --------------------
# /wiki/Adrian_Cronauer
# --------------------
# /wiki/Good_Morning,_Vietnam
# --------------------
# /wiki/Academy_Award_for_Best_Actor
# --------------------
# /wiki/Dead_Poets_Society
# --------------------
# /wiki/Awakenings
# --------------------
# /wiki/The_Fisher_King
# --------------------
# /wiki/Hook_(film)
# --------------------
# /wiki/Aladdin_(1992_Disney_film)
# --------------------
# /wiki/Mrs._Doubtfire
# --------------------
# /wiki/Academy_Award_for_Best_Supporting_Actor
# --------------------
# /wiki/Good_Will_Hunting
# --------------------
# /wiki/Insomnia_(2002_film)
# --------------------
# /wiki/One_Hour_Photo
# --------------------
# /wiki/Happy_Feet
# --------------------
# /wiki/Night_at_the_Museum
# --------------------
# /wiki/The_Crazy_Ones
# --------------------
# /wiki/List_of_first_overall_Major_League_Baseball_draft_picks
# --------------------
# /wiki/World_Fantasy_Special_Award%E2%80%94Professional
# --------------------
# /wiki/List_of_prime_ministers_of_Italy
# --------------------
# /wiki/Wikipedia:Today%27s_featured_list/July_2022
# --------------------
# /wiki/Wikipedia:Featured_lists
# --------------------
# /wiki/File:Wells_Cathedral_Stairs_to_Chapter_House,_Somerset,_UK_-_Diliff.jpg
# --------------------
# /wiki/Wells_Cathedral
# --------------------
# /wiki/Anglicanism
# --------------------
# /wiki/Wells,_Somerset
# --------------------
# /wiki/Mausoleum
# --------------------
# /wiki/John_Harvey_(architectural_historian)
# --------------------
# /wiki/Gothic_architecture
# --------------------
# /wiki/Romanesque_architecture
# --------------------
# /wiki/Bishop_of_Bath_and_Wells
# --------------------
# /wiki/Chapter_house
# --------------------
# /wiki/User:Diliff
# --------------------
# /wiki/Template:POTD/2022-07-21
# --------------------
# /wiki/Template:POTD/2022-07-20
# --------------------
# /wiki/Template:POTD/2022-07-19
# --------------------
# /wiki/Wikipedia:Picture_of_the_day/Archive
# --------------------
# /wiki/Wikipedia:Featured_pictures
# --------------------
# /wiki/Wikipedia:Village_pump
# --------------------
# /wiki/Wikipedia:News
# --------------------
# /wiki/Wikipedia:Teahouse
# --------------------
# /wiki/Wikipedia:Help_desk
# --------------------
# /wiki/Wikipedia:Reference_desk
# --------------------
# /wiki/Wikipedia:Contents/Portals
# --------------------
# /wiki/Talk:Main_Page
# --------------------
# /wiki/Special:WhatLinksHere/Main_Page
# --------------------
# /wiki/Special:RecentChangesLinked/Main_Page
